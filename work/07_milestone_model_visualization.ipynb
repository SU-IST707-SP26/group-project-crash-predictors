# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 import matplotlib.pyplot as plt
#       5 # Create hour column if needed
# ----> 6 if 'hour' not in X_test.columns and 'crash_time' in X_test.columns:
#       7     X_test['hour'] = pd.to_datetime(X_test['crash_time']).dt.hour
#       9 # Combine predictions with features
#
# NameError: name 'X_test' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 fig, axes = plt.subplots(2, 2, figsize=(14, 10))
#       3 # 1. Probability distribution
# ----> 4 sns.histplot(y_prob_lgbm_smote, bins=30, kde=True, ax=axes[0, 0])
#       5 axes[0, 0].set_title('Prediction Probability Distribution')
#       7 # 2. Feature importance (if using tree model like RF/LGBM)
#
# NameError: name 'y_prob_lgbm_smote' is not defined
